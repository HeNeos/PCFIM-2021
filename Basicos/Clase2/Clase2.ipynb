# %%
import time
import matplotlib.pyplot as plt
def avg(fun, times):
    s = 0
    for j in range(times):
        t0 = time.time()
        fun(inp[i])
        tf = time.time()
        s += tf-t0
    return s/times

# %%
def f(x):
    ans = 0
    for i in range(x):
        ans += i

def g(n):
    for i in range(n):
        f(10)

def h(n):
    for i in range(n):
        f(i)

# %%
inp = range(0, 2000, 25)
t = [0]*len(inp)
for i in range(len(inp)):
    t[i] = avg(f, 500)

plt.plot(inp, t, 'b.')

# %%
inp = range(0, 2000, 50)
t = [0]*len(inp)
for i in range(len(inp)):
    t[i] = avg(g, 100)

plt.plot(inp, t, 'b.')

# %%
inp = range(0, 2000, 50)
t = [0]*len(inp)
for i in range(len(inp)):
    t[i] = avg(h, 20)

plt.plot(inp, t, 'b.')
